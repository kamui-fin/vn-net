# %% [markdown]
# # Experiments with `surprise`
#
# This phase is to experiment with more classical models like SVD using surprise to create some baselines to compare my NCF model against.

# %% [markdown]
# ## Generating recommendations for a user

# %% [markdown]
# I want to start off with just examining the quality of the recommendations. Just to get some feedback if things are going okay or not. I'll return to model analysis after.

# %%
# ankh
TEST_USER = 43708

# %% [markdown]
# Let's load the usual data back from our data store:

# %%
import pandas as pd
from collections import defaultdict
from surprise import Dataset, SVD, Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# Load wrangled data
store = pd.HDFStore('store.h5')
votes, vn = store['votes'], store['vn']

# %%
reader = Reader(rating_scale=(0, 1))
data = Dataset.load_from_df(votes, reader=reader)

# %% [markdown]
# I'll use SVD for now but later in the notebook I'll be comparing different models and running analysis.

# %%
trainset = data.build_full_trainset()
algo = SVD()
algo.fit(trainset)

# %% [markdown]
# We'll build a test-set by filtering out already read VNs from the list of all VNs.

# %%
def build_anti_testset_for_user(algo, user_id):
    all_iids = vn.index.unique()
    iids_of_user = [iid for (iid, _) in algo.trainset.ur[user_id]]
    anti_testset = [(user_id, iid, 0) for iid in all_iids if iid not in iids_of_user]
    return anti_testset

anti_testset_user = build_anti_testset_for_user(algo, TEST_USER)
predictions = algo.test(anti_testset_user)

# %% [markdown]
# And voila, we can generate our predictions. A very important note here is to establish some sort of filtering procedure to weed out unpreferable VNs. Here, I'll use the following heuristic:
# - Must be rated already and have over 50 votes minimum
#
# I'll experiment with more finegrained procedures later, but this seems to give us some decent recommendations to start with.

# %%
# Recommendation generation
# Collect predictions and sort based on estimated rating
top_n = sorted([(pred.est, pred.iid) for pred in predictions], reverse=True)
# Compile dataframe to display recommendations
reccs = vn.loc[[x[1] for x in top_n]][['title', 'c_rating', 'c_votecount', 'tags']]
reccs['predicted'] = [x[0] for x in top_n]
reccs.loc[(reccs['c_votecount'] > 50) & ~(reccs['c_rating'].isna())].head(30)
# Out:
#                                                    title  c_rating  \
# id
# 2507                                            [Steal!]     689.0
# 20600                                   [真剣で私に恋しなさい！A-3]     783.0
# 8491   [Angel, Devil, Elf and Me!, ¡Ángel, Demonio, E...     562.0
# 7886                [アルバイトの先輩の女のコに仕事を教わっていたら始まっちゃうHな関係。]     707.0
# 2337                                       [同級生2, 동급생 2]     767.0
# 1458                                        [夢幻廻廊2 ～螺旋～]     680.0
# 97     [Saya no Uta, Saya no Uta ~ The Song of Saya, ...     801.0
# 16563                                   [根雪の幻影 -白花荘の人々-]     686.0
# 7304                       [That Cheap and Sacred Thing]     715.0
# 16143  [バカな妹を利口にするのは俺の××だけな件について, 关于唯一能让笨蛋妹妹变聪明的方法只有我...     648.0
# 14359                             [Ladykiller in a Bind]     674.0
# 32239                       [催淫サロン ～夫の知らぬ間に孕ませリベンジされる妻～]     699.0
# 22703  [Mary Skelter 2, 神獄塔 メアリスケルター2, 신옥탑 메리스켈터 2, 神...     772.0
# 82                                           [Quartett!]     720.0
# 16651               [The Charming Empire, 帝國カレイド―万華の革命―]     553.0
# 24721                                       [Imolicious]     418.0
# 10804  [Bokuten - Why I Became an Angel, 僕が天使になった理由, ...     717.0
# 7138                                       [Anyo's Love]     550.0
# 15439            [The world ends tomorrow, 明日終わる世界、その前夜]     524.0
# 15287                                   [父娘愛 ～いけない子作り2～]     657.0
# 2965                                   [夢喰い－つるみく式ゲーム製作－]     720.0
# 527                       [Shera, My Witch, さっきゅば☆SOON！]     541.0
# 29399  [Hypno Mama, Hipnotizando la mamá de mi acosad...     575.0
# 24399                   [Hello Charlotte: Heaven's Gate]     735.0
# 20862              [Sakura Magical Girls, サクラ・マジカル・ガールズ]     499.0
# 15065                                 [Inkey University]     615.0
# 156                                     [PRINCESS WALTZ]     703.0
# 16846                                       [姫様LOVEライフ！]     709.0
# 114    [Discipline -The Record of a Crusade-, DISCIPL...     664.0
# 19220                                          [交姦の虜たち…]     718.0
#
#        c_votecount                                               tags  \
# id
# 2507            70  [Multiple Endings, Protagonist with Voice Acti...
# 20600         1121  [Sex with Protagonist Only, Male Protagonist, ...
# 8491           166  [Male Protagonist, Unavoidable Harem Ending, N...
# 7886            75  [Nukige, High Sexual Content, Remote-controlle...
# 2337            65             [90's, Nanpa, More Than Seven Endings]
# 1458            52  [Time Loop, Master and Servant, Female Dominat...
# 97           16448                             [NVL, Madness, Horror]
# 16563          150              [Haunted House, One True End, Ryokan]
# 7304           175  [Kinetic Novel, Only a Single Hero, Female Pro...
# 16143           65    [Nukige, Airhead Heroine, Only Virgin Heroines]
# 14359          164  [Promiscuity, Strong Female Protagonist, Sexua...
# 32239           62  [Adult Protagonist, Falsely Accused, Muscular ...
# 22703           63  [Prison, Lesbian Protagonist, Dungeon Crawling...
# 82            1003    [Competition, Musical Themes, Floating Textbox]
# 16651          127  [Otome Game, Slice of Life Drama, Heroine with...
# 24721          105  [Genre Shift, Villainous Protagonist, Delusion...
# 10804          750          [Drama, Unlockable Routes, Angel Heroine]
# 7138           118  [Only a Single Hero, Otome Game, Multiple Endi...
# 15439           63   [No Sexual Content, No Event CGs, Kinetic Novel]
# 15287           88  [Blood-related Father/Daughter Incest, Sex wit...
# 2965            73  [Sexual Slavery (Choukyou Variation), Producti...
# 527            453  [Bonus Side Stories, Early Sexual Content, Und...
# 29399           72  [Sex in Public Places, Internal Pissing, Pissing]
# 24399          114  [No Background Music, Suicide, Non-Binary Prot...
# 20862          177     [Single Ending, Heroine with Big Breasts, ADV]
# 15065           83                          [Horror, University, ADV]
# 156           2136  [Sex with Protagonist Only, Bad Endings with S...
# 16846           52   [Under the Same Roof, Princess Heroine, Cowgirl]
# 114           1286  [Heroine with Big Breasts, Rape Involving Drug...
# 19220           86               [Swinging, Male Protagonist, Nukige]
#
#        predicted
# id
# 2507    0.869705
# 20600   0.864820
# 8491    0.863529
# 7886    0.850756
# 2337    0.849567
# 1458    0.848956
# 97      0.847702
# 16563   0.840552
# 7304    0.826599
# 16143   0.826144
# 14359   0.823310
# 32239   0.822706
# 22703   0.821510
# 82      0.819206
# 16651   0.818416
# 24721   0.815615
# 10804   0.812162
# 7138    0.810932
# 15439   0.809611
# 15287   0.807122
# 2965    0.805771
# 527     0.802972
# 29399   0.802854
# 24399   0.802554
# 20862   0.802325
# 15065   0.799272
# 156     0.799014
# 16846   0.796961
# 114     0.795972
# 19220   0.795155

# %% [markdown]
# # Model analysis
#
# There seems to be many models that `surprise` supports. I'm mainly interested in SVD, because that's what NCF will be building upon.
#
# Let's start off with some cross validation metrics.

# %%
cross_validate(algo, data, measures=["MSE"], cv=5, verbose=True)
# Out:
# Evaluating MSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# MSE (testset)     0.0241  0.0240  0.0239  0.0240  0.0241  0.0240  0.0001
# Fit time          16.30   16.74   16.40   15.86   15.83   16.22   0.34
# Test time         2.62    2.22    2.09    2.12    2.00    2.21    0.22
# {'test_mse': array([0.02405904, 0.02402493, 0.02392401, 0.0240399 , 0.02407068]),
#  'fit_time': (16.29642915725708,
#   16.73988389968872,
#   16.395029306411743,
#   15.856948852539062,
#   15.834071636199951),
#  'test_time': (2.6249895095825195,
#   2.2170963287353516,
#   2.0936126708984375,
#   2.1169626712799072,
#   2.004941701889038)}
